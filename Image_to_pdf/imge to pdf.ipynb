# %%
import pytesseract
import os
from docx import Document
from PIL import Image

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files (x86)\\Tesseract-OCR\\tesseract'

# %%
document = Document()

# %%
txt=pytesseract.image_to_string(Image.open('Dumps/13.jpg'))

# %%
txt=txt.replace("Of","of")

# %%
txt
# Out:
# '© Sentinel Secure\n\nKRYTERION\n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\n \n\nIZ KRYTERION” a\n\nGLOBAL TESTING SOLUTIONS\n\n \n\nSingle Book\n\n \n\nd Platform App Builder (SP19)\n\n \n\n \n\n \n\n \n\n \n\n= Sales representatives want to capture custom Feedback record details related to each Account. The sales reps want to\n\n \n\naccomplish this with minimal clicks on the Salesforce Mobile application. Miuinple Books\nS\nWhich two solutions should be recommended in order to meet this requirement? | CS) |\nChoose 2 answers\n\n \n\nA. C1 Create a feedback object as a parent of Account.\n\nreate an object-specific action on Account.\nrreate predefined values for most of the fields.\n\n \n\n \n\n&\nD. Co Create a global action on Account. Pencil & Paper\n(Mark this item for later review. g\nWritten\nMaterials'

# %%
text = txt
left = 'Platform App Builder (SP19)'
right = 'Mark this item'

txt2=text[text.index(left)+len(left):text.index(right)]

# %%
imglis=os.listdir('Dumps')

# %%
for i in range(1,len(imglis)):
    print(imglis[i])
    path='Dumps/'+imglis[i]
    txt=pytesseract.image_to_string(Image.open(path))
    hd='Qestion for ' +imglis[i]
    document.add_heading(hd, 0)
    text = txt
    left = 'Platform App Builder (SP19)'
    right = 'Mark this item for later review'
    try:
        txt2=text[text.index(left)+len(left):text.index(right)]
        print(txt2)
        p = document.add_paragraph(txt2)
    except:
        print('EXP occur')
        print(txt)
        p = document.add_paragraph(txt)
# Out:
# 10.jpg
#
#
# 10 of 60. Which two objects can be members of a Campaign? Multiple Books
# Choose 2 answers
#
# A.M Lead
#
# B. CJ Opportunity
# c. H Contact
# D. DO Account:
#
#
#
#
#
# (
# 11.jpg
#
# Time Remaining: 1:37:22
#
# 11 Of 60. What are two capabilities of Schema Builder? Multiple Books
# Choose 2 answers
#
# A. C1 Editing custom settings
# howing selected objects on a page
#
# c. Ml Viewing page layouts in a new window
# D.C Creating a new record type
#
#
#
#
# (
# 12.jpg
#
#
#
#
# Time Rem
#
#
#
# Multiple Books
#
# 12 of 60. Universal Containers needs to update a field on an Account when an Opportunity Stage is changed to Closed Lost.
#
# Which two tools should be used to accomplish this requirement?
# Choose 2 answers
#
# Workflow Rule
# B. Process Builder
# c. DAssignment Rule
#
# D.C Approval Process g
# Pencil & Paper
# Written
# Materials
#
#
#
# (
# 13.jpg
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
document.save('test12.docx')

# %%
p

# %%
my_string="hello python world , i'm a beginner "

# %%
my_string.split("world",1)[1]
# Out:
# " , i'm a beginner "

# %%
tring = "The  world  tag pti"

# %%
e=tring.split('tag')

# %%
e3=e[1].replace(' ','')

# %%
e3
# Out:
# 'pti'

# %%
st='share me the detadffffils fddddor topic CycloneVayu'

# %%
res = st2.find('cyclonevayu')

# %%
res
# Out:
# 40

# %%
st2=st.lower()

# %%
import pandas as pd

# %%
data2 = pd.read_csv('m1.txt', sep = "[ \t]*,[ \t]*", header=None)
# Out:
# c:\users\idcpt1212\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
data
# Out:
#                                                     0
# 0                                Question  for 57.jpg
# 1                                            Time Rem
# 2                                        ing: 1:11:46
# 3   57 Of 60. Universal Containers wants to automa...
# 4   Which two actions should be completed to meet ...
# 5                                    Choose 2 answers
# 6   Create a Flow on the User object to assign a p...
# 7   B. Create a Process on the User object to laun...
# 8   cc. C1 Create a workflow rule on the User obje...
# 9   D. (1 Create an Approval process on the User o...
# 10                                                  (

# %%
datatrans=data2.T

# %%
datatrans
# Out:
#                      0         1             2   \
# 0  Question  for 57.jpg  Time Rem  ing: 1:11:46
#
#                                                   3   \
# 0  57 Of 60. Universal Containers wants to automa...
#
#                                                   4                 5   \
# 0  Which two actions should be completed to meet ...  Choose 2 answers
#
#                                                   6   \
# 0  Create a Flow on the User object to assign a p...
#
#                                                   7   \
# 0  B. Create a Process on the User object to laun...
#
#                                                   8   \
# 0  cc. C1 Create a workflow rule on the User obje...
#
#                                                   9  10
# 0  D. (1 Create an Approval process on the User o...  (

# %%
lis=[]
lis.append(datatrans.values)

# %%
import numpy

# %%
type(lis)
# Out:
# list

# %%
lis.append(datatrans.values)

# %%
lis
# Out:
# [array([['Question  for 57.jpg', 'Time Rem', 'ing: 1:11:46',
#          '57 Of 60. Universal Containers wants to automatically assign a specific permission set to new users.',
#          'Which two actions should be completed to meet this requirement?',
#          'Choose 2 answers',
#          'Create a Flow on the User object to assign a permission set.',
#          'B. Create a Process on the User object to launch a flow.',
#          'cc. C1 Create a workflow rule on the User object to assign a permission set.',
#          'D. (1 Create an Approval process on the User object to assign a permission set.',
#          '(']], dtype=object),
#  array([['Question  for 57.jpg', 'Time Rem', 'ing: 1:11:46',
#          '57 Of 60. Universal Containers wants to automatically assign a specific permission set to new users.',
#          'Which two actions should be completed to meet this requirement?',
#          'Choose 2 answers',
# ...

# %%
df = pd.DataFrame(lis)

# %%
df
# Out:
#                                                    0
# 0  [[Question  for 57.jpg, Time Rem, ing: 1:11:46...
# 1  [[Question  for 57.jpg, Time Rem, ing: 1:11:46...

# %%
from pyspark import SparkContext

# %%
sc = SparkContext("local", "count app")

# %%
words = sc.parallelize (
   ["scala", 
   "java", 
   "hadoop", 
   "spark", 
   "akka",
   "spark vs hadoop", 
   "pyspark",
   "pyspark and spark"]
)

# %%
counts = words.count()

# %%
counts
# Out:
# 8
